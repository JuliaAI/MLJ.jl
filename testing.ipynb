# %%
include("MLJ.jl")
include("Tuning.jl")
include("glm_wrapper.jl")
# Out:
# learnᵧ! (generic function with 1 method)

# %%
ps = ParametersSet([
    ContinuousParameter(
        name = "λ",
        lower = -4,
        upper = 1,
        transform = x->10^x
    )
        ,
    DiscreteParameter(
        name = "penalty",
        values = [L1Penalty(), L2Penalty(), ElasticNetPenalty()]
    )
])

data = Fakedata(1000,3)

task = Task(task_type="regression", target=4, data=data)
lrn = Learner("glm")

tune(learner=lrn, task=task, data=data, parameters_set=ps, measure=mean_squared_error)
# Out:
# Trained:
# Learner: glm
#  ▁ ▂ ▃ penalty: L1Penalty
#  ▁ ▂ ▃ λ: 0.001
#
# Average CV accuracy: 3.961428838871451e-6
#
# Trained:
# Learner: glm
#  ▁ ▂ ▃ penalty: L1Penalty
#  ▁ ▂ ▃ λ: 0.01
#
# Average CV accuracy: 0.0004133792014697157
#
# Trained:
# Learner: glm
#  ▁ ▂ ▃ penalty: L1Penalty
#  ▁ ▂ ▃ λ: 0.1
#
# Average CV accuracy: 0.022731093917439233
#
# Trained:
# Learner: glm
#  ▁ ▂ ▃ penalty: L1Penalty
#  ▁ ▂ ▃ λ: 1.0
#
# Average CV accuracy: 1.7346201856462267
#
# Trained:
# Learner: glm
#  ▁ ▂ ▃ penalty: L1Penalty
#  ▁ ▂ ▃ λ: 10.0
#
# Average CV accuracy: 3.330461422780442
#
# Trained:
# Learner: glm
#  ▁ ▂ ▃ penalty: L2Penalty
#  ▁ ▂ ▃ λ: 0.0001
#
# Average CV accuracy: 2.697396889340025e-8
#
# Trained:
# Learner: glm
#  ▁ ▂ ▃ penalty: L2Penalty
#  ▁ ▂ ▃ λ: 0.001
#
# Average CV accuracy: 3.003368089537654e-6
#
# Trained:
# Learner: glm
#  ▁ ▂ ▃ penalty: L2Penalty
#  ▁ ▂ ▃ λ: 0.01
#
# Average CV accuracy: 0.0002932113965008968
#
# Trained:
# Learner: glm
#  ▁ ▂ ▃ penalty: L2Penalty
#  ▁ ▂ ▃ λ: 0.1
#
# Average CV accuracy: 0.025998130284713945
#
# Trained:
# Learner: glm
#  ▁ ▂ ▃ penalty: L2Penalty
#  ▁ ▂ ▃ λ: 1.0
#
# Average CV accuracy: 0.7531276280339774
#
# Trained:
# Learner: glm
#  ▁ ▂ ▃ penalty: L2Penalty
#  ▁ ▂ ▃ λ: 10.0
#
# Average CV accuracy: 2.6566540637001577
# INFO: Converged after 18 iterations: [0.0614691, 0.923637, -1.40419]
# INFO: Converged after 15 iterations: [0.0616768, 0.923509, -1.40406]
# INFO: Converged after 29 iterations: [0.0609247, 0.923342, -1.40393]
# INFO: Converged after 48 iterations: [0.0476732, 0.912588, -1.3902]
# INFO: Converged after 22 iterations: [0.0504438, 0.917715, -1.3955]
# INFO: Converged after 21 iterations: [0.0509613, 0.91708, -1.3958]
# INFO: Converged after 14 iterations: [0.0, 0.828679, -1.29956]
# INFO: Converged after 15 iterations: [0.0, 0.845586, -1.30333]
# INFO: Converged after 17 iterations: [0.0, 0.871758, -1.30219]
# INFO: Converged after 15 iterations: [-0.0, 0.28288, -0.253036]
# INFO: Converged after 12 iterations: [-0.0, 0.289082, -0.499245]
# INFO: Converged after 16 iterations: [-0.0, 0.1867, -0.553481]
# INFO: Converged after 2 iterations: [-0.0, 0.0, -0.0]
# INFO: Converged after 2 iterations: [-0.0, 0.0, -0.0]
# INFO: Converged after 2 iterations: [-0.0, 0.0, -0.0]
# INFO: Sweep finished
# INFO: Sweep finished
# INFO: Sweep finished
# INFO: Sweep finished
# INFO: Sweep finished
# INFO: Sweep finished
# INFO: Sweep finished
# INFO: Sweep finished
# INFO: Sweep finished
# INFO: Sweep finished
# INFO: Sweep finished
# INFO: Sweep finished
# INFO: Sweep finished
# INFO: Sweep finished
# INFO: Sweep finished
# INFO: Sweep finished
# INFO: Sweep finished
# INFO: Sweep finished
# Trained:
# Learner: glm
#  ▁ ▂ ▃ penalty: ElasticNetPenalty{Float64}(α = 0.5)
#  ▁ ▂ ▃ λ: 0.0001
#
# Average CV accuracy: 2.7981364040326022e-8
#
# Trained:
# Learner: glm
#  ▁ ▂ ▃ penalty: ElasticNetPenalty{Float64}(α = 0.5)
#  ▁ ▂ ▃ λ: 0.001
#
# Average CV accuracy: 2.6748542589021975e-6
#
# Trained:
# Learner: glm
#  ▁ ▂ ▃ penalty: ElasticNetPenalty{Float64}(α = 0.5)
#  ▁ ▂ ▃ λ: 0.01
#
# Average CV accuracy: 0.00034577666133966977
#
# Trained:
# Learner: glm
#  ▁ ▂ ▃ penalty: ElasticNetPenalty{Float64}(α = 0.5)
#  ▁ ▂ ▃ λ: 0.1
#
# Average CV accuracy: 0.02270880490952153
#
# Trained:
# Learner: glm
#  ▁ ▂ ▃ penalty: ElasticNetPenalty{Float64}(α = 0.5)
#  ▁ ▂ ▃ λ: 1.0
#
# Average CV accuracy: 0.9835974351527949
#
# Trained:
# Learner: glm
#  ▁ ▂ ▃ penalty: ElasticNetPenalty{Float64}(α = 0.5)
#  ▁ ▂ ▃ λ: 10.0
#
# Average CV accuracy: 3.329309526281944
# INFO: Converged after 24 iterations: [0.0625462, 0.92428, -1.40504]
# INFO: Converged after 18 iterations: [0.0625714, 0.924291, -1.40506]
# INFO: Converged after 20 iterations: [0.0625683, 0.924291, -1.40505]
# INFO: Converged after 21 iterations: [0.0617914, 0.923593, -1.40399]
# INFO: Converged after 19 iterations: [0.061888, 0.92369, -1.4039]
# INFO: Converged after 22 iterations: [0.0618657, 0.923664, -1.40383]
# INFO: Converged after 20 iterations: [0.0546836, 0.916988, -1.3928]
# INFO: Converged after 31 iterations: [0.0506494, 0.916249, -1.38847]
# INFO: Converged after 17 iterations: [0.0572144, 0.918153, -1.39474]
# INFO: Converged after 16 iterations: [0.0, 0.8621, -1.28185]
# INFO: Converged after 16 iterations: [0.0, 0.852834, -1.27838]
# INFO: Converged after 12 iterations: [0.0, 0.858064, -1.29702]
# INFO: Converged after 11 iterations: [-0.0, 0.480123, -0.584136]
# INFO: Converged after 10 iterations: [-0.0, 0.428837, -0.611624]
# INFO: Converged after 13 iterations: [-0.0, 0.442504, -0.648416]
# INFO: Converged after 2 iterations: [-0.0, 0.0, -0.0]
# INFO: Converged after 2 iterations: [-0.0, 0.0, -0.0]
# INFO: Converged after 2 iterations: [-0.0, 0.0, -0.0]
# BoundsError: attempt to access 2-element Array{Any,1} at index [3]
#
# Stacktrace:
#  [1] update_parameters!(::Array{Any,1}, ::Array{Tuple,1}) at /home/edoardo/Documents/programming/warwick-rsg/MLR/Tuning.jl:10
#  [2] #tune#52(::Learner, ::Task, ::Array{Float64,2}, ::ParametersSet, ::Resampling, ::MLMetrics.#mean_squared_error, ::Function) at /home/edoardo/Documents/programming/warwick-rsg/MLR/Tuning.jl:89
#  [3] (::#kw##tune)(::Array{Any,1}, ::#tune) at ./<missing>:0
#  [4] include_string(::String, ::String) at ./loading.jl:522
